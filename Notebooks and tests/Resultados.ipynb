# %% [markdown]
# Modelo treinado em V, rede:
#
# ```
# class tenlayersNetwork(nn.Module):
#     def __init__(self, input_size, output_size):
#         super(tenlayersNetwork, self).__init__()
#         self.fc1 = nn.Linear(input_size, 64)
#         self.fc2 = nn.Linear(64, 64)
#         self.fc3 = nn.Linear(64, 64)
#         self.fc4 = nn.Linear(64, 64)
#         self.fc5 = nn.Linear(64, 64)
#         self.fc6 = nn.Linear(64, 64)
#         self.fc7 = nn.Linear(64, 64)
#         self.fc8 = nn.Linear(64, 64)
#         self.fc9 = nn.Linear(64, 64)
#         self.fc10 = nn.Linear(64, output_size)
#         self.relu = nn.ReLU()
#
#     def forward(self, x):
#         x = self.relu(self.fc1(x))
#         x = self.relu(self.fc2(x))
#         x = self.relu(self.fc3(x))
#         x = self.relu(self.fc4(x))
#         x = self.relu(self.fc5(x))
#         x = self.relu(self.fc6(x))
#         x = self.relu(self.fc7(x))
#         x = self.relu(self.fc8(x))
#         x = self.relu(self.fc9(x))
#         x = self.fc10(x)
#         return x
#
# ```

# %% [markdown]
# acuracia:
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# usando modelo pre treinando em "Nabla"
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# usando modelo pre treinando em "2D"
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Modelo treinado em V, rede:
#
# ```
# class tenlayersNetwork(nn.Module):
#     def __init__(self, input_size, output_size):
#         super(tenlayersNetwork, self).__init__()
#         self.fc1 = nn.Linear(input_size, 200)
#         self.fc2 = nn.Linear(200, 64)
#         self.fc3 = nn.Linear(64, 64)
#         self.fc4 = nn.Linear(64, 64)
#         self.fc5 = nn.Linear(64, 64)
#         self.fc6 = nn.Linear(64, 64)
#         self.fc7 = nn.Linear(64, 64)
#         self.fc8 = nn.Linear(64, 64)
#         self.fc9 = nn.Linear(64, 32)
#         self.fc10 = nn.Linear(32, output_size)
#         self.relu = nn.ReLU()
#
#     def forward(self, x):
#         x = self.relu(self.fc1(x))
#         x = self.relu(self.fc2(x))
#         x = self.relu(self.fc3(x))
#         x = self.relu(self.fc4(x))
#         x = self.relu(self.fc5(x))
#         x = self.relu(self.fc6(x))
#         x = self.relu(self.fc7(x))
#         x = self.relu(self.fc8(x))
#         x = self.relu(self.fc9(x))
#         x = self.fc10(x)
#         return x
# ```

# %% [markdown]
# Acuracia:
#
# Test Loss: 0.0230
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# usando modelo pre treinando em "Nabla"
#
# Test Loss: 1.0147
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# usando modelo pre treinando em "2D"
#
# Test Loss: 0.9471
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Modelo treinado em "2D"
# ```
# class tenlayersNetwork(nn.Module):
#     def __init__(self, input_size, output_size):
#         super(tenlayersNetwork, self).__init__()
#         self.fc1 = nn.Linear(input_size, 1024)
#         self.fc2 = nn.Linear(1024, 512)
#         self.fc3 = nn.Linear(512, 256)
#         self.fc4 = nn.Linear(256, 128)
#         self.fc5 = nn.Linear(128, 64)
#         self.fc6 = nn.Linear(64, 32)
#         self.fc7 = nn.Linear(32, 16)
#         self.fc8 = nn.Linear(16, 8)
#         self.fc9 = nn.Linear(8, 4)
#         self.fc10 = nn.Linear(4, output_size)
#         self.relu = nn.ReLU()
#
#     def forward(self, x):
#         x = self.relu(self.fc1(x))
#         x = self.relu(self.fc2(x))
#         x = self.relu(self.fc3(x))
#         x = self.relu(self.fc4(x))
#         x = self.relu(self.fc5(x))
#         x = self.relu(self.fc6(x))
#         x = self.relu(self.fc7(x))
#         x = self.relu(self.fc8(x))
#         x = self.relu(self.fc9(x))
#         x = self.fc10(x)
#         return x
# ```

# %% [markdown]
# Acuracia apos treino
#
# Test Loss: 0.1036
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Usando modelo em Nabla
#
# Test Loss: 1.1674
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Usando modelo em V
#
# Test Loss: 1.6330
#
# ![image.png](data:image/png;base64,...)

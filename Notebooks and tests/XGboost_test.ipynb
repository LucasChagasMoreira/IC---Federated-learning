# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import torch
from torch import nn
from torch import optim
import os

# %%
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
def carregar_dadosv2(train_data, test_data, test_size=0.2, random_state=42):
    # Load data from CSV file
    train_data = pd.read_csv(train_data)
    val_data = pd.read_csv(test_data)

    # Split data into features (X) and targets (y)
    X = train_data.drop(['hysteresis', 'joule'], axis=1)
    y = train_data[['hysteresis', 'joule']]

    # Perform train-test split
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=test_size, random_state=random_state)

    X_test = val_data.drop(['hysteresis', 'joule'], axis=1)
    y_test = val_data[['hysteresis', 'joule']]

    # Convert data to numpy arrays
    X_train_np = X_train.to_numpy()
    y_train_np = y_train.to_numpy()
    X_val_np = X_val.to_numpy()
    y_val_np = y_val.to_numpy()
    X_test_np = X_test.to_numpy()
    y_test_np = y_test.to_numpy()

    return X_train_np, y_train_np, X_val_np, y_val_np, X_test_np, y_test_np

# %%
import matplotlib.pyplot as plt


def plot_comparacao(y_true, y_pred):

    plt.figure(figsize=(8, 6))

    # Plot each target separately
    for i in range(2):  # Assuming two targets
        plt.scatter([true[i] for true in y_true], [pred[i] for pred in y_pred], label=f'Target {i+1}', alpha=0.5)

    max_val = max(max(y_true[:,0]), max(y_pred[:,0]), max(y_true[:,1]), max(y_pred[:,1]))
    plt.plot([0, max_val], [0, max_val], color='red', linestyle='--', linewidth=2, label='Reference Line')

    plt.xlabel('Predicted Values')
    plt.ylabel('True Values')
    plt.title('Comparison between True and Predicted Values')
    plt.legend()

    plt.show()

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.11.4)

# %%
import xgboost as xgb
from xgboost import XGBRegressor

import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

folder_path = '/content/drive/MyDrive/FederatedLearning-main/Data/IPMSM_datasets/dataset_for_iron_losses_of_IPMSMs/2D'
os.chdir(folder_path)

X_train ,y_train, X_val, y_val,X_test,y_test = carregar_dadosv2('dados_de_treino.csv','dados_de_teste.csv')

train_dmatrix = xgb.DMatrix(data=X_train, label=y_train)
test_dmatrix = xgb.DMatrix(data=X_val, label=y_val)
verify_test_dmatrix = xgb.DMatrix(data=X_test, label=y_test)

params = {
    'objective': 'reg:squarederror',
    'eval_metric': 'rmse',
    'eta': 0.18438088025284619,
    'max_depth': 7,
    'subsample': 0.816395068974634,
    'colsample_bytree': 0.9741558370628208,
    'gamma': 1.9349140709821284e-05,
    'min_child_weight': 4
}
input_size = X_train.shape[1]
output_size = y_train.shape[1]

def objective(trial):
    params = {
        'eta': trial.suggest_float('eta', 0.01, 0.3, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'subsample': trial.suggest_float('subsample', 0.7, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.7, 1.0),
        'gamma': trial.suggest_float('gamma', 0, 0.5),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 7)
    }
    model = XGBRegressor(**params)
    model.fit(X_train, y_train, eval_set=[(X_val, y_val)], early_stopping_rounds=10, verbose=False)
    predictions = model.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, predictions))
    return rmse

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-3.6.1-py3-none-any.whl (380 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.1/380.1 kB 2.7 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 15.7 MB/s eta 0:00:00
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.30)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.5 alembic-1.13.1 colorlog-6.8.2 optuna-3.6.1

# %%
#import optuna
#study = optuna.create_study(direction='minimize')
#study.optimize(objective, n_trials=100)

# %%
num_boost_round = 1000
watchlist = [(train_dmatrix, 'train'), (test_dmatrix, 'eval')]
bst = xgb.train(params, train_dmatrix, num_boost_round, watchlist, early_stopping_rounds=10)
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:727: FutureWarning: Pass `evals` as keyword args.
#   warnings.warn(msg, FutureWarning)
# [0]	train-rmse:0.81350	eval-rmse:0.82017
# [1]	train-rmse:0.67001	eval-rmse:0.67565
# [2]	train-rmse:0.56038	eval-rmse:0.56606
# [3]	train-rmse:0.46356	eval-rmse:0.46848
# [4]	train-rmse:0.38467	eval-rmse:0.38916
# [5]	train-rmse:0.32060	eval-rmse:0.32520
# [6]	train-rmse:0.28988	eval-rmse:0.29544
# [7]	train-rmse:0.24318	eval-rmse:0.24880
# [8]	train-rmse:0.20574	eval-rmse:0.21151
# [9]	train-rmse:0.17694	eval-rmse:0.18291
# [10]	train-rmse:0.15840	eval-rmse:0.16531
# [11]	train-rmse:0.13718	eval-rmse:0.14494
# [12]	train-rmse:0.12650	eval-rmse:0.13517
# [13]	train-rmse:0.11109	eval-rmse:0.12069
# [14]	train-rmse:0.09948	eval-rmse:0.10980
# [15]	train-rmse:0.09017	eval-rmse:0.10140
# [16]	train-rmse:0.08181	eval-rmse:0.09386
# [17]	train-rmse:0.07504	eval-rmse:0.08795
# [18]	train-rmse:0.07017	eval-rmse:0.08387
# [19]	train-rmse:0.06622	eval-rmse:0.08062
# [20]	train-rmse:0.06277	eval-rmse:0.07770
# [21]	train-rmse:0.05966	eval-rmse:0.07517
# [22]	train-rmse:0.05716	eval-rmse:0.07323
# [23]	train-rmse:0.05508	eval-rmse:0.07172
# [24]	train-rmse:0.05320	eval-rmse:0.07021
# [25]	train-rmse:0.05143	eval-rmse:0.06897
# [26]	train-rmse:0.04993	eval-rmse:0.06787
# [27]	train-rmse:0.04860	eval-rmse:0.06688
# [28]	train-rmse:0.04732	eval-rmse:0.06583
# [29]	train-rmse:0.04649	eval-rmse:0.06518
# [30]	train-rmse:0.04568	eval-rmse:0.06466
# [31]	train-rmse:0.04504	eval-rmse:0.06428
# [32]	train-rmse:0.04434	eval-rmse:0.06381
# [33]	train-rmse:0.04358	eval-rmse:0.06325
# [34]	train-rmse:0.04312	eval-rmse:0.06292
# [35]	train-rmse:0.04268	eval-rmse:0.06265
# [36]	train-rmse:0.04209	eval-rmse:0.06218
# [37]	train-rmse:0.04161	eval-rmse:0.06193
# [38]	train-rmse:0.04105	eval-rmse:0.06163
# [39]	train-rmse:0.04076	eval-rmse:0.06146
# [40]	train-rmse:0.04028	eval-rmse:0.06117
# [41]	train-rmse:0.03985	eval-rmse:0.06092
# [42]	train-rmse:0.03955	eval-rmse:0.06069
# [43]	train-rmse:0.03914	eval-rmse:0.06042
# [44]	train-rmse:0.03859	eval-rmse:0.06008
# [45]	train-rmse:0.03821	eval-rmse:0.05979
# [46]	train-rmse:0.03782	eval-rmse:0.05949
# [47]	train-rmse:0.03752	eval-rmse:0.05942
# [48]	train-rmse:0.03725	eval-rmse:0.05930
# [49]	train-rmse:0.03699	eval-rmse:0.05912
# [50]	train-rmse:0.03671	eval-rmse:0.05903
# [51]	train-rmse:0.03639	eval-rmse:0.05892
# [52]	train-rmse:0.03619	eval-rmse:0.05882
# [53]	train-rmse:0.03587	eval-rmse:0.05870
# [54]	train-rmse:0.03569	eval-rmse:0.05866
# [55]	train-rmse:0.03549	eval-rmse:0.05861
# [56]	train-rmse:0.03520	eval-rmse:0.05841
# [57]	train-rmse:0.03491	eval-rmse:0.05830
# [58]	train-rmse:0.03474	eval-rmse:0.05819
# [59]	train-rmse:0.03447	eval-rmse:0.05807
# [60]	train-rmse:0.03429	eval-rmse:0.05800
# [61]	train-rmse:0.03400	eval-rmse:0.05791
# [62]	train-rmse:0.03383	eval-rmse:0.05786
# [63]	train-rmse:0.03356	eval-rmse:0.05775
# [64]	train-rmse:0.03321	eval-rmse:0.05759
# [65]	train-rmse:0.03296	eval-rmse:0.05744
# [66]	train-rmse:0.03268	eval-rmse:0.05736
# [67]	train-rmse:0.03247	eval-rmse:0.05732
# [68]	train-rmse:0.03211	eval-rmse:0.05712
# [69]	train-rmse:0.03190	eval-rmse:0.05704
# [70]	train-rmse:0.03176	eval-rmse:0.05697
# [71]	train-rmse:0.03135	eval-rmse:0.05674
# [72]	train-rmse:0.03120	eval-rmse:0.05670
# [73]	train-rmse:0.03100	eval-rmse:0.05663
# [74]	train-rmse:0.03081	eval-rmse:0.05655
# [75]	train-rmse:0.03063	eval-rmse:0.05649
# [76]	train-rmse:0.03036	eval-rmse:0.05639
# [77]	train-rmse:0.03026	eval-rmse:0.05634
# [78]	train-rmse:0.03010	eval-rmse:0.05632
# [79]	train-rmse:0.02993	eval-rmse:0.05622
# [80]	train-rmse:0.02970	eval-rmse:0.05613
# [81]	train-rmse:0.02946	eval-rmse:0.05603
# [82]	train-rmse:0.02930	eval-rmse:0.05601
# [83]	train-rmse:0.02919	eval-rmse:0.05598
# [84]	train-rmse:0.02901	eval-rmse:0.05599
# [85]	train-rmse:0.02883	eval-rmse:0.05594
# [86]	train-rmse:0.02867	eval-rmse:0.05587
# [87]	train-rmse:0.02855	eval-rmse:0.05585
# [88]	train-rmse:0.02837	eval-rmse:0.05581
# [89]	train-rmse:0.02826	eval-rmse:0.05577
# [90]	train-rmse:0.02811	eval-rmse:0.05575
# [91]	train-rmse:0.02800	eval-rmse:0.05568
# [92]	train-rmse:0.02786	eval-rmse:0.05565
# [93]	train-rmse:0.02769	eval-rmse:0.05555
# [94]	train-rmse:0.02754	eval-rmse:0.05549
# [95]	train-rmse:0.02740	eval-rmse:0.05543
# [96]	train-rmse:0.02730	eval-rmse:0.05541
# [97]	train-rmse:0.02724	eval-rmse:0.05540
# [98]	train-rmse:0.02716	eval-rmse:0.05538
# [99]	train-rmse:0.02699	eval-rmse:0.05535
# [100]	train-rmse:0.02687	eval-rmse:0.05530
# [101]	train-rmse:0.02665	eval-rmse:0.05523
# [102]	train-rmse:0.02655	eval-rmse:0.05521
# [103]	train-rmse:0.02644	eval-rmse:0.05519
# [104]	train-rmse:0.02632	eval-rmse:0.05516
# [105]	train-rmse:0.02620	eval-rmse:0.05513
# [106]	train-rmse:0.02606	eval-rmse:0.05509
# [107]	train-rmse:0.02585	eval-rmse:0.05507
# [108]	train-rmse:0.02577	eval-rmse:0.05506
# [109]	train-rmse:0.02560	eval-rmse:0.05503
# [110]	train-rmse:0.02549	eval-rmse:0.05501
# [111]	train-rmse:0.02538	eval-rmse:0.05497
# [112]	train-rmse:0.02527	eval-rmse:0.05495
# [113]	train-rmse:0.02515	eval-rmse:0.05493
# [114]	train-rmse:0.02504	eval-rmse:0.05492
# [115]	train-rmse:0.02493	eval-rmse:0.05490
# [116]	train-rmse:0.02482	eval-rmse:0.05489
# [117]	train-rmse:0.02470	eval-rmse:0.05488
# [118]	train-rmse:0.02450	eval-rmse:0.05483
# [119]	train-rmse:0.02431	eval-rmse:0.05473
# [120]	train-rmse:0.02419	eval-rmse:0.05473
# [121]	train-rmse:0.02410	eval-rmse:0.05475
# [122]	train-rmse:0.02403	eval-rmse:0.05474
# [123]	train-rmse:0.02394	eval-rmse:0.05474
# [124]	train-rmse:0.02380	eval-rmse:0.05472
# [125]	train-rmse:0.02367	eval-rmse:0.05470
# [126]	train-rmse:0.02358	eval-rmse:0.05465
# [127]	train-rmse:0.02350	eval-rmse:0.05463
# [128]	train-rmse:0.02338	eval-rmse:0.05459
# [129]	train-rmse:0.02324	eval-rmse:0.05460
# [130]	train-rmse:0.02312	eval-rmse:0.05459
# [131]	train-rmse:0.02296	eval-rmse:0.05453
# [132]	train-rmse:0.02285	eval-rmse:0.05450
# [133]	train-rmse:0.02277	eval-rmse:0.05447
# [134]	train-rmse:0.02270	eval-rmse:0.05448
# [135]	train-rmse:0.02259	eval-rmse:0.05447
# [136]	train-rmse:0.02250	eval-rmse:0.05446
# [137]	train-rmse:0.02237	eval-rmse:0.05445
# [138]	train-rmse:0.02224	eval-rmse:0.05442
# [139]	train-rmse:0.02212	eval-rmse:0.05437
# [140]	train-rmse:0.02201	eval-rmse:0.05433
# [141]	train-rmse:0.02192	eval-rmse:0.05430
# [142]	train-rmse:0.02183	eval-rmse:0.05430
# [143]	train-rmse:0.02172	eval-rmse:0.05429
# [144]	train-rmse:0.02161	eval-rmse:0.05427
# [145]	train-rmse:0.02151	eval-rmse:0.05428
# [146]	train-rmse:0.02141	eval-rmse:0.05424
# [147]	train-rmse:0.02133	eval-rmse:0.05424
# [148]	train-rmse:0.02114	eval-rmse:0.05422
# [149]	train-rmse:0.02102	eval-rmse:0.05418
# [150]	train-rmse:0.02094	eval-rmse:0.05418
# [151]	train-rmse:0.02080	eval-rmse:0.05411
# [152]	train-rmse:0.02071	eval-rmse:0.05409
# [153]	train-rmse:0.02062	eval-rmse:0.05406
# [154]	train-rmse:0.02054	eval-rmse:0.05406
# [155]	train-rmse:0.02042	eval-rmse:0.05402
# [156]	train-rmse:0.02031	eval-rmse:0.05399
# [157]	train-rmse:0.02021	eval-rmse:0.05396
# [158]	train-rmse:0.02010	eval-rmse:0.05395
# [159]	train-rmse:0.02003	eval-rmse:0.05394
# [160]	train-rmse:0.01994	eval-rmse:0.05395
# [161]	train-rmse:0.01987	eval-rmse:0.05394
# [162]	train-rmse:0.01975	eval-rmse:0.05391
# [163]	train-rmse:0.01967	eval-rmse:0.05391
# [164]	train-rmse:0.01955	eval-rmse:0.05387
# [165]	train-rmse:0.01947	eval-rmse:0.05385
# [166]	train-rmse:0.01939	eval-rmse:0.05385
# [167]	train-rmse:0.01928	eval-rmse:0.05383
# [168]	train-rmse:0.01915	eval-rmse:0.05381
# [169]	train-rmse:0.01903	eval-rmse:0.05378
# [170]	train-rmse:0.01894	eval-rmse:0.05375
# [171]	train-rmse:0.01889	eval-rmse:0.05374
# [172]	train-rmse:0.01881	eval-rmse:0.05374
# [173]	train-rmse:0.01874	eval-rmse:0.05375
# [174]	train-rmse:0.01864	eval-rmse:0.05371
# [175]	train-rmse:0.01852	eval-rmse:0.05370
# [176]	train-rmse:0.01845	eval-rmse:0.05369
# [177]	train-rmse:0.01837	eval-rmse:0.05366
# [178]	train-rmse:0.01828	eval-rmse:0.05361
# [179]	train-rmse:0.01822	eval-rmse:0.05361
# [180]	train-rmse:0.01814	eval-rmse:0.05361
# [181]	train-rmse:0.01806	eval-rmse:0.05360
# [182]	train-rmse:0.01796	eval-rmse:0.05356
# [183]	train-rmse:0.01791	eval-rmse:0.05355
# [184]	train-rmse:0.01779	eval-rmse:0.05352
# [185]	train-rmse:0.01771	eval-rmse:0.05351
# [186]	train-rmse:0.01766	eval-rmse:0.05351
# [187]	train-rmse:0.01758	eval-rmse:0.05349
# [188]	train-rmse:0.01756	eval-rmse:0.05349
# [189]	train-rmse:0.01752	eval-rmse:0.05348
# [190]	train-rmse:0.01745	eval-rmse:0.05348
# [191]	train-rmse:0.01741	eval-rmse:0.05348
# [192]	train-rmse:0.01735	eval-rmse:0.05346
# [193]	train-rmse:0.01731	eval-rmse:0.05346
# [194]	train-rmse:0.01723	eval-rmse:0.05345
# [195]	train-rmse:0.01715	eval-rmse:0.05344
# [196]	train-rmse:0.01705	eval-rmse:0.05343
# [197]	train-rmse:0.01701	eval-rmse:0.05341
# [198]	train-rmse:0.01696	eval-rmse:0.05342
# [199]	train-rmse:0.01687	eval-rmse:0.05342
# [200]	train-rmse:0.01683	eval-rmse:0.05343
# [201]	train-rmse:0.01678	eval-rmse:0.05343
# [202]	train-rmse:0.01672	eval-rmse:0.05343
# [203]	train-rmse:0.01663	eval-rmse:0.05341
# [204]	train-rmse:0.01656	eval-rmse:0.05342
# [205]	train-rmse:0.01648	eval-rmse:0.05340
# [206]	train-rmse:0.01640	eval-rmse:0.05338
# [207]	train-rmse:0.01632	eval-rmse:0.05335
# [208]	train-rmse:0.01624	eval-rmse:0.05333
# [209]	train-rmse:0.01617	eval-rmse:0.05333
# [210]	train-rmse:0.01609	eval-rmse:0.05331
# [211]	train-rmse:0.01601	eval-rmse:0.05330
# [212]	train-rmse:0.01595	eval-rmse:0.05329
# [213]	train-rmse:0.01590	eval-rmse:0.05327
# [214]	train-rmse:0.01585	eval-rmse:0.05327
# [215]	train-rmse:0.01578	eval-rmse:0.05324
# [216]	train-rmse:0.01574	eval-rmse:0.05323
# [217]	train-rmse:0.01569	eval-rmse:0.05322
# [218]	train-rmse:0.01561	eval-rmse:0.05321
# [219]	train-rmse:0.01556	eval-rmse:0.05321
# [220]	train-rmse:0.01548	eval-rmse:0.05319
# [221]	train-rmse:0.01541	eval-rmse:0.05319
# [222]	train-rmse:0.01533	eval-rmse:0.05319
# [223]	train-rmse:0.01527	eval-rmse:0.05319
# [224]	train-rmse:0.01523	eval-rmse:0.05319
# [225]	train-rmse:0.01517	eval-rmse:0.05320
# [226]	train-rmse:0.01510	eval-rmse:0.05319
# [227]	train-rmse:0.01503	eval-rmse:0.05318
# [228]	train-rmse:0.01497	eval-rmse:0.05317
# [229]	train-rmse:0.01492	eval-rmse:0.05317
# [230]	train-rmse:0.01487	eval-rmse:0.05317
# [231]	train-rmse:0.01482	eval-rmse:0.05317
# [232]	train-rmse:0.01475	eval-rmse:0.05318
# [233]	train-rmse:0.01468	eval-rmse:0.05316
# [234]	train-rmse:0.01464	eval-rmse:0.05316
# [235]	train-rmse:0.01460	eval-rmse:0.05316
# [236]	train-rmse:0.01454	eval-rmse:0.05316
# [237]	train-rmse:0.01448	eval-rmse:0.05316
# [238]	train-rmse:0.01445	eval-rmse:0.05316
# [239]	train-rmse:0.01439	eval-rmse:0.05314
# [240]	train-rmse:0.01435	eval-rmse:0.05314
# [241]	train-rmse:0.01429	eval-rmse:0.05313
# [242]	train-rmse:0.01422	eval-rmse:0.05310
# [243]	train-rmse:0.01415	eval-rmse:0.05309
# [244]	train-rmse:0.01408	eval-rmse:0.05308
# [245]	train-rmse:0.01404	eval-rmse:0.05308
# [246]	train-rmse:0.01399	eval-rmse:0.05308
# [247]	train-rmse:0.01393	eval-rmse:0.05308
# [248]	train-rmse:0.01389	eval-rmse:0.05308
# [249]	train-rmse:0.01383	eval-rmse:0.05306
# [250]	train-rmse:0.01378	eval-rmse:0.05305
# [251]	train-rmse:0.01373	eval-rmse:0.05306
# [252]	train-rmse:0.01370	eval-rmse:0.05305
# [253]	train-rmse:0.01365	eval-rmse:0.05304
# [254]	train-rmse:0.01360	eval-rmse:0.05304
# [255]	train-rmse:0.01354	eval-rmse:0.05305
# [256]	train-rmse:0.01347	eval-rmse:0.05305
# [257]	train-rmse:0.01341	eval-rmse:0.05304
# [258]	train-rmse:0.01337	eval-rmse:0.05303
# [259]	train-rmse:0.01333	eval-rmse:0.05303
# [260]	train-rmse:0.01330	eval-rmse:0.05303
# [261]	train-rmse:0.01324	eval-rmse:0.05302
# [262]	train-rmse:0.01319	eval-rmse:0.05302
# [263]	train-rmse:0.01313	eval-rmse:0.05301
# [264]	train-rmse:0.01308	eval-rmse:0.05299
# [265]	train-rmse:0.01302	eval-rmse:0.05299
# [266]	train-rmse:0.01298	eval-rmse:0.05300
# [267]	train-rmse:0.01294	eval-rmse:0.05299
# [268]	train-rmse:0.01289	eval-rmse:0.05298
# [269]	train-rmse:0.01282	eval-rmse:0.05298
# [270]	train-rmse:0.01277	eval-rmse:0.05298
# [271]	train-rmse:0.01273	eval-rmse:0.05298
# [272]	train-rmse:0.01268	eval-rmse:0.05298
# [273]	train-rmse:0.01264	eval-rmse:0.05298
# [274]	train-rmse:0.01258	eval-rmse:0.05297
# [275]	train-rmse:0.01253	eval-rmse:0.05298
# [276]	train-rmse:0.01247	eval-rmse:0.05299
# [277]	train-rmse:0.01243	eval-rmse:0.05298
# [278]	train-rmse:0.01239	eval-rmse:0.05298
# [279]	train-rmse:0.01234	eval-rmse:0.05298
# [280]	train-rmse:0.01229	eval-rmse:0.05298
# [281]	train-rmse:0.01225	eval-rmse:0.05297
# [282]	train-rmse:0.01221	eval-rmse:0.05298
# [283]	train-rmse:0.01216	eval-rmse:0.05298
# [284]	train-rmse:0.01213	eval-rmse:0.05298
# [285]	train-rmse:0.01209	eval-rmse:0.05298
# [286]	train-rmse:0.01204	eval-rmse:0.05298
# [287]	train-rmse:0.01199	eval-rmse:0.05299
# [288]	train-rmse:0.01194	eval-rmse:0.05298
# [289]	train-rmse:0.01190	eval-rmse:0.05298
# [290]	train-rmse:0.01187	eval-rmse:0.05297
# [291]	train-rmse:0.01182	eval-rmse:0.05296
# [292]	train-rmse:0.01177	eval-rmse:0.05295
# [293]	train-rmse:0.01172	eval-rmse:0.05296
# [294]	train-rmse:0.01167	eval-rmse:0.05294
# [295]	train-rmse:0.01163	eval-rmse:0.05294
# [296]	train-rmse:0.01159	eval-rmse:0.05294
# [297]	train-rmse:0.01154	eval-rmse:0.05293
# [298]	train-rmse:0.01150	eval-rmse:0.05293
# [299]	train-rmse:0.01146	eval-rmse:0.05292
# [300]	train-rmse:0.01142	eval-rmse:0.05292
# [301]	train-rmse:0.01139	eval-rmse:0.05293
# [302]	train-rmse:0.01135	eval-rmse:0.05293
# [303]	train-rmse:0.01131	eval-rmse:0.05293
# [304]	train-rmse:0.01127	eval-rmse:0.05292
# [305]	train-rmse:0.01123	eval-rmse:0.05292
# [306]	train-rmse:0.01118	eval-rmse:0.05293
# [307]	train-rmse:0.01113	eval-rmse:0.05292
# [308]	train-rmse:0.01110	eval-rmse:0.05292
# [309]	train-rmse:0.01106	eval-rmse:0.05291
# [310]	train-rmse:0.01101	eval-rmse:0.05290
# [311]	train-rmse:0.01097	eval-rmse:0.05289
# [312]	train-rmse:0.01093	eval-rmse:0.05289
# [313]	train-rmse:0.01090	eval-rmse:0.05288
# [314]	train-rmse:0.01085	eval-rmse:0.05288
# [315]	train-rmse:0.01082	eval-rmse:0.05288
# [316]	train-rmse:0.01079	eval-rmse:0.05288
# [317]	train-rmse:0.01074	eval-rmse:0.05288
# [318]	train-rmse:0.01071	eval-rmse:0.05288
# [319]	train-rmse:0.01068	eval-rmse:0.05288
# [320]	train-rmse:0.01064	eval-rmse:0.05287
# [321]	train-rmse:0.01062	eval-rmse:0.05287
# [322]	train-rmse:0.01058	eval-rmse:0.05287
# [323]	train-rmse:0.01054	eval-rmse:0.05286
# [324]	train-rmse:0.01050	eval-rmse:0.05286
# [325]	train-rmse:0.01047	eval-rmse:0.05285
# [326]	train-rmse:0.01044	eval-rmse:0.05285
# [327]	train-rmse:0.01038	eval-rmse:0.05284
# [328]	train-rmse:0.01035	eval-rmse:0.05283
# [329]	train-rmse:0.01032	eval-rmse:0.05283
# [330]	train-rmse:0.01027	eval-rmse:0.05283
# [331]	train-rmse:0.01025	eval-rmse:0.05283
# [332]	train-rmse:0.01020	eval-rmse:0.05282
# [333]	train-rmse:0.01017	eval-rmse:0.05282
# [334]	train-rmse:0.01015	eval-rmse:0.05282
# [335]	train-rmse:0.01012	eval-rmse:0.05281
# [336]	train-rmse:0.01008	eval-rmse:0.05282
# [337]	train-rmse:0.01004	eval-rmse:0.05281
# [338]	train-rmse:0.01000	eval-rmse:0.05281
# [339]	train-rmse:0.00997	eval-rmse:0.05281
# [340]	train-rmse:0.00992	eval-rmse:0.05281
# [341]	train-rmse:0.00989	eval-rmse:0.05281
# [342]	train-rmse:0.00986	eval-rmse:0.05281
# [343]	train-rmse:0.00982	eval-rmse:0.05280
# [344]	train-rmse:0.00979	eval-rmse:0.05280
# [345]	train-rmse:0.00976	eval-rmse:0.05280
# [346]	train-rmse:0.00973	eval-rmse:0.05280
# [347]	train-rmse:0.00971	eval-rmse:0.05280
# [348]	train-rmse:0.00968	eval-rmse:0.05280
# [349]	train-rmse:0.00963	eval-rmse:0.05278
# [350]	train-rmse:0.00959	eval-rmse:0.05279
# [351]	train-rmse:0.00955	eval-rmse:0.05279
# [352]	train-rmse:0.00951	eval-rmse:0.05280
# [353]	train-rmse:0.00948	eval-rmse:0.05280
# [354]	train-rmse:0.00945	eval-rmse:0.05280
# [355]	train-rmse:0.00942	eval-rmse:0.05280
# [356]	train-rmse:0.00939	eval-rmse:0.05280
# [357]	train-rmse:0.00936	eval-rmse:0.05280
# [358]	train-rmse:0.00932	eval-rmse:0.05279
# [359]	train-rmse:0.00929	eval-rmse:0.05279

# %%
predictions = bst.predict(verify_test_dmatrix)
plot_comparacao(y_test,predictions)
